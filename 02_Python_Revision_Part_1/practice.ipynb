# %%
employee_name = "Vaibhav Pawar"
print(employee_name)
department = "Developing"
print(department)
salary = 1500000
print(salary)
experience = 5
print(experience)
bonus = 250000
print(bonus)
# Out:
# Vaibhav Pawar
# Developing
# 1500000
# 5
# 250000

# %%
company_name = "Amazon"
print(company_name)
total_employees = 200
print(total_employees)
revenue = 250000000
print(revenue)
profit_margin = 65000000
print(profit_margin)
head_office = "Pune"
print(head_office)
stock_available = True
print(stock_available)
# Out:
# Amazon
# 200
# 250000000
# 65000000
# Pune
# True

# %%
annual_sales = 3600000

average_monthly_sales = annual_sales / 12

print(type(average_monthly_sales))
print(average_monthly_sales)
# Out:
# <class 'float'>
# 300000.0

# %%
product_price = 2500
quantity_sold = 320
expenses = 500000
sales_target = 700000

total_revenue = product_price * quantity_sold
print("Revenue :- " , total_revenue)

total_profit =total_revenue - expenses
print("Profit :- ", total_profit)

print("Is revenue greater than sales:- ",total_revenue > sales_target)

expenses = expenses + 25000
print("Updated Expences:-" , expenses)

print("Target Achieved:- " ,
     total_revenue > sales_target
     and expenses < total_revenue
     )
# Out:
# Revenue :-  800000
# Profit :-  300000
# Is revenue greater than sales:-  True
# Updated Expences:- 525000
# Target Achieved:-  True

# %%
customers = [
    "  rahul sharma",
    "PRIYA PATIL ",
    " amit joshi ",
    "SNEHA DESHMUKH"
]

for name in customers:
     cleaned = name.strip().title()
     print(cleaned)
# Out:
# Rahul Sharma
# Priya Patil
# Amit Joshi
# Sneha Deshmukh

# %%
monthly_orders = [
    1200,
    1450,
    1320,
    1680,
    1740,
    1820
]

print("Total Orders : " , sum(monthly_orders))

print("Average Monthly Orders : " , sum(monthly_orders)/len(monthly_orders))

highest_orders = max(monthly_orders)
print("Highest Orders :", highest_orders)

print("Lowest Orders : ", min(monthly_orders))

monthly_orders.append(1950)
print("Updated Monthly Orders :", monthly_orders)

print("First three months : " , monthly_orders[:3])

print("Last three months : " , monthly_orders[-3:])
# Out:
# Total Orders :  9210
# Average Monthly Orders :  1535.0
# Highest Orders : 1820
# Lowest Orders :  1200
# Updated Monthly Orders : [1200, 1450, 1320, 1680, 1740, 1820, 1950]
# First three months :  [1200, 1450, 1320]
# Last three months :  [1740, 1820, 1950]

# %% [markdown]
# # Key Takeaways
#
# ## Concepts Revised
# - Variables
# - Data Types
# - Operators
# - Strings
# - Lists
#
# ## Business Connection
# - Used meaningful variable names.
# - Understood why data types matter in analysis.
# - Connected operators to business KPIs.
# - Learned string cleaning techniques for real datasets.
# - Used lists to calculate business metrics and prepare for NumPy and Pandas.
#
# ## Confidence Level
# 9.5/10
#
# ## Notes
# Today's revision focused on applying Python concepts to business scenarios instead of learning basic syntax.
